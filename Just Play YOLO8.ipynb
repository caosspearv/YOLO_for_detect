# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:06<00:00, 7.67MB/s]

# %%
results = model.track(source='https://www.youtube.com/watch?v=3TyodLAvXRo', show = True)
# Out:
# 1/1: https://www.youtube.com/watch?v=3TyodLAvXRo... Success  (17185 frames of shape 1920x1080 at 30.00 FPS)
#
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results = model.track(source='https://www.youtube.com/watch?v=3TyodLAvXRo', show = True)
#
# ...
